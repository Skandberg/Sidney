# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

def advise(wish):
    mangaData=pd.read_csv('hmanga.csv')
    X=str(mangaData['tags'])
    Y=str(mangaData.drop(columns=['tags']))
    model = DecisionTreeClassifier()
    model.fit(X, Y)
    mofel.predict(wish)
advise('big breasts')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-76bfbbdf6d3a> in <module>
#       9     model.fit(X, Y)
#      10     mofel.predict(wish)
# ---> 11 advise('big breasts')
#
# <ipython-input-1-76bfbbdf6d3a> in advise(wish)
#       7     Y=str(mangaData.drop(columns=['tags']))
#       8     model = DecisionTreeClassifier()
# ----> 9     model.fit(X, Y)
#      10     mofel.predict(wish)
#      11 advise('big breasts')
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# ...
