# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd


def getMangas():
    url='https://nhentai.net/'
    source = requests.get(url).text
    soup = BeautifulSoup(source, 'lxml')

    mangas=soup.find_all('div', class_='caption')
    links=soup.find_all('a', href=True, class_='cover')

    mangaTitles=[]
    mangaLinks=[]
    mangaLists=[]
    mangaTags=[]
    for i in mangas:
        mangaTitles.append(i.text)
    for i in links:
        mangaLinks.append(url+i.get('href'))
        mangaSource = requests.get(url+i.get('href')).text
        mangaSoup=BeautifulSoup(mangaSource,'lxml')
        tags= mangaSoup.find_all('span',class_='name')
        temp_tags=[]
        for j in tags:
            temp_tags.append(j.text)
        mangaTags.append('; '.join(temp_tags))


    mangaList = list(zip(mangaTitles, mangaLinks, mangaTags))

    df=pd.DataFrame(mangaList, columns=['title', 'link', 'tags'])
    df.to_csv('hmanga.csv', index = False)
    pd.set_option('display.max_columns', None)
    print(df)
# Out:
#                                                 title  \
# 0   [Touyoko Surfrider (Fummy)] Bokutachi wa, Koi ...
# 1   [Koharu Nanakusa] Ikinuki Yaruki (Seme Joshi S...
# 2   [Nanahoshi Tento] TABOO -Zenpen- (Yarisugi Sho...
# 3   [studio A (Inanaki Shiki)] Houshi-bu no Iyaras...
# 4   [Carradine] Loli-Bitch Magic! (COMIC LO 2020-1...
# 5   [Koudansha (Kouda Tomohiro)] Ai Last Boss Hito...
# 6   [Nigiri Usagi] ◯miya (THE iDOLM@STER: Shiny Co...
# 7   [Koudansha (Kouda Tomohiro)] Momoiro？ Hitomato...
# 8   (Chou Original Dai Doujin Sai) Chou Original D...
# 9   [Kouzuki Rio] Imouto Saimin Choukyou Manual | ...
# 10  (C88) [Tamagobou (Kumakiti)] Yamato Dakkan (Ka...
# 11  [kumikouj] Sekuhara OK Gakuen ~ Chime Nattara ...
# 12  [Nrr] Koko ni Oda Bakufu wo Tateyou | Let's Bu...
# 13              [サーモンだいすきクラブ (どね)]寝ティティちゃんはちょろい [DL版]
# 14                                    Scatterd Flower
# 15  [Hard work (GURUM)] 寝床で失礼します (Fate/Grand Order...
# 16    [Hard work (GURUM)] 寝床で失礼します (Fate/Grand Order)
# 17                 [Dr.BUG]Angel and Dragon(Hololive)
# 18  [Yao] Inma-sama ni Hallelujah! | 赞美淫魔大人! Ch. 1...
# 19  [SEM;COLON (Mitsuki Tsumi)] Kimi to Hanabi to ...
# 20  [Aisu Hatsudenjyo (Aisu no A)] Ryou Shiro is p...
# 21                 Stepmother Friends Ch.42 [English]
# 22  (COMIC1☆17) [URAN-FACTORY (URAN)] Ere-chan no ...
# 23     メイドと店主と懐中時計と(Touhou Project) [紫苑汉化组] [Chinese]
# 24  [Echo Jiro] Watanabe Yuu (23) xxx Danyu Hajime...
# 25                       【周五连载】主妇危机（作者：查爾斯&漢水） 第1~28话
# 26               【周五连载】渴望:爱火难耐（作者：Appeal&格子17） 第1~17话
# 27  [Terasu MC] LoveR 6P (LoveR) [ENGLISH] [Netora...
